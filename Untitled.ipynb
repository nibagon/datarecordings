# %%
import numpy as np
import pylab as pl
import scipy.signal as signal
import fir1

fs = 1000
f1 = 45
f2 = 55

b = signal.firwin(999,[f1/fs*2,f2/fs*2])

ecg = np.loadtxt("ecg50hz.dat")
pl.figure(1)
pl.plot(ecg)

f = fir1.Fir1(b)

y= np.empty(len(ecg))
for i in range(len(ecg)):
    y[i] = f.filter(ecg[i])

pl.figure(2)
pl.plot(y[1000:])
pl.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-41fe1a018e1e> in <module>
#       2 import pylab as pl
#       3 import scipy.signal as signal
# ----> 4 import fir1
#       5
#       6 fs = 1000
#
# ModuleNotFoundError: No module named 'fir1'

# %%
import numpy as np
import pylab as pl
import scipy.signal as signal
import fir1

fs = 1000

NTAPS = 100
LEARNING_RATE = 0.0005

ecg = np.loadtxt("ecg50hz.dat")
pl.figure(1)
pl.plot(ecg)

f = fir1.Fir1(NTAPS)
f.setLearningRate(LEARNING_RATE);

y= np.empty(len(ecg))
for i in range(len(ecg)):
    ref_noise = np.sin(2.0 * np.pi / 20.0 * i);
    canceller = f.filter(ref_noise)
    output_signal = ecg[i] - canceller
    f.lms_update(output_signal)
    y[i] = output_signal

pl.figure(2)
pl.plot(y)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-09a2b6bf3e6f> in <module>
#       2 import pylab as pl
#       3 import scipy.signal as signal
# ----> 4 import fir1
#       5
#       6 fs = 1000
#
# ModuleNotFoundError: No module named 'fir1'

# %%
import numpy as np
import pylab as pl
import scipy.signal as signal

fs = 1000
f1 = 45
f2 = 55
scale = 2**12

b = signal.firwin(999,[f1/fs*2,f2/fs*2])
b = b*scale
b = b.astype(int)
np.savetxt("coeff12bit.dat",b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7d65f79b5cff> in <module>
#       4 f1 = 45
#       5 f2 = 55
# ----> 6 b = signal.firwin(999,[f1/fs*2,f2/fs*2])
#
# NameError: name 'signal' is not defined

# %%
import numpy as np
import pylab as pl
data = np.loadtxt('ECGch1_EMGch2_rightwristNoise_00.tsv');

# %%
pl.plot(data[0:1000,0],data[0:1000,7]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
pl.plot(data[0:1000,0],data[0:1000,6]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %% [markdown]
# # RAW_DIO1

# %%
pl.plot(data[:,0],data[:,8]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
ecg=data[:,8]
np.savetxt("ecg_noise.dat",ecg)

# %% [markdown]
# # RAW_DIO2

# %%
pl.plot(data[:,0],data[:,9]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
noise=data[:,9]
np.savetxt("just_noise.dat",ecg)

# %%
chanel_1= data[:,9]

# %%
# Out:
# array([ 3.6000000e-02, -2.6690561e+01,  1.0687716e+01,  6.9862800e+00,
#         0.0000000e+00,  1.8000000e-05, -1.9000000e-05, -7.9980000e-03,
#        -1.0000000e-04,  6.0000000e-06])

# %%
chanel_1
# Out:
# array([ 0.0e+00,  3.0e-06,  5.0e-06, ...,  1.4e-05,  3.0e-06, -2.0e-06])
