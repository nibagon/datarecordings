# %%
import numpy as np
import pylab as pl
clean = np.loadtxt('cleanECGL2.tsv');

# %%
pl.plot(clean[0:500,0],clean[0:500,7]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();
pl.savefig('clean.jpg')

# %%
corupt = np.loadtxt('ECGL2_ch2Rarm.tsv');

# %%
pl.plot(corupt[0:500,0],corupt[0:500,7]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();
#pl.savefig('ECGandEMG.png')

# %%
pl.plot(corupt[:,0],corupt[:,8]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
np.savetxt("0116becg_noise.dat",corupt[:,7])

# %%
pl.plot(corupt[:,0],corupt[:,7]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
np.savetxt("0116bjust_noise.dat",corupt[:,8])

# %%
corupt2 = np.loadtxt('ECGL2_ch2Rarmt.tsv');

# %%
pl.plot(corupt2[:,0],corupt2[:,7]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
np.savetxt("01_164ecg_noise.dat",corupt2[:,7])

# %%
pl.plot(corupt2[:,0],corupt2[:,8]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();

# %%
np.savetxt("01_164just_noise.dat",corupt2[:,8])

# %%
pl.plot(corupt2[0:500,0],corupt2[0:500,11]);
pl.xlabel('time/sec');
pl.ylabel('II/V');
pl.show();
